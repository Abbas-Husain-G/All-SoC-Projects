# %%
# !pip install qiskit
# !pip install qiskit[visualization]
# !pip install qiskit_aer
# !pip install qiskit_ibm_runtime
# Out:
# Requirement already satisfied: qiskit in c:\users\abbas\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (1.13.2)
# Requirement already satisfied: dill>=0.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (4.11.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abbas\anaconda3\lib\site-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\abbas\anaconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (75.1.0)
# Requirement already satisfied: qiskit[visualization] in c:\users\abbas\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (1.13.2)
# Requirement already satisfied: dill>=0.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (4.11.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (0.13.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (3.9.2)
# Requirement already satisfied: pydot in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (4.0.0)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (10.4.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abbas\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\abbas\anaconda3\lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.2.2)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit[visualization]) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abbas\anaconda3\lib\site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abbas\anaconda3\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abbas\anaconda3\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2023.3)
# Requirement already satisfied: setuptools in c:\users\abbas\anaconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit[visualization]) (75.1.0)
# Requirement already satisfied: qiskit_aer in c:\users\abbas\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_aer) (2.0.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_aer) (1.13.1)
# Requirement already satisfied: psutil>=5 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_aer) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (1.13.2)
# Requirement already satisfied: dill>=0.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.4.1)
# Requirement already satisfied: typing-extensions in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.11.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.13.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abbas\anaconda3\lib\site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_aer) (1.3.0)
# Requirement already satisfied: setuptools in c:\users\abbas\anaconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (75.1.0)
# Collecting qiskit_ibm_runtime
#   Downloading qiskit_ibm_runtime-0.40.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.19 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (2.32.3)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Downloading ibm_platform_services-0.66.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=2.5.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (2.8.2)
# Requirement already satisfied: qiskit>=1.4.1 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (2.0.2)
# Requirement already satisfied: packaging in c:\users\abbas\anaconda3\lib\site-packages (from qiskit_ibm_runtime) (24.1)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.2 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abbas\anaconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\abbas\anaconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\abbas\anaconda3\lib\site-packages (from pydantic>=2.5.0->qiskit_ibm_runtime) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (1.13.2)
# Requirement already satisfied: dill>=0.3 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\abbas\anaconda3\lib\site-packages (from qiskit>=1.4.1->qiskit_ibm_runtime) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abbas\anaconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abbas\anaconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abbas\anaconda3\lib\site-packages (from requests>=2.19->qiskit_ibm_runtime) (2025.4.26)
# Requirement already satisfied: cryptography>=1.3 in c:\users\abbas\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (43.0.0)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading pyspnego-0.11.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\abbas\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.17.1)
# Collecting requests>=2.19 (from qiskit_ibm_runtime)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3>=1.21.1 (from qiskit_ibm_runtime)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting PyJWT<3.0.0,>=2.10.1 (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting sspilib>=0.1.0 (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading sspilib-0.3.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\abbas\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.4.1->qiskit_ibm_runtime) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abbas\anaconda3\lib\site-packages (from sympy>=1.3->qiskit>=1.4.1->qiskit_ibm_runtime) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\abbas\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.21)
# Requirement already satisfied: setuptools in c:\users\abbas\anaconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.4.1->qiskit_ibm_runtime) (75.1.0)
# Downloading qiskit_ibm_runtime-0.40.1-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 178.6 kB/s eta 0:00:15
#    ------ --------------------------------- 0.5/3.2 MB 178.6 kB/s eta 0:00:15
#    ------ --------------------------------- 0.5/3.2 MB 178.6 kB/s eta 0:00:15
#    ------ --------------------------------- 0.5/3.2 MB 178.6 kB/s eta 0:00:15
#    ------ --------------------------------- 0.5/3.2 MB 178.6 kB/s eta 0:00:15
#    --------- ------------------------------ 0.8/3.2 MB 209.7 kB/s eta 0:00:12
#    --------- ------------------------------ 0.8/3.2 MB 209.7 kB/s eta 0:00:12
#    --------- ------------------------------ 0.8/3.2 MB 209.7 kB/s eta 0:00:12
#    --------- ------------------------------ 0.8/3.2 MB 209.7 kB/s eta 0:00:12
#    ------------- -------------------------- 1.0/3.2 MB 240.9 kB/s eta 0:00:09
#    ------------- -------------------------- 1.0/3.2 MB 240.9 kB/s eta 0:00:09
#    ---------------- ----------------------- 1.3/3.2 MB 289.3 kB/s eta 0:00:07
#    ------------------- -------------------- 1.6/3.2 MB 330.3 kB/s eta 0:00:05
#    ------------------- -------------------- 1.6/3.2 MB 330.3 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.8/3.2 MB 363.4 kB/s eta 0:00:04
#    ---------------------- ----------------- 1.8/3.2 MB 363.4 kB/s eta 0:00:04
#    ---------------------- ----------------- 1.8/3.2 MB 363.4 kB/s eta 0:00:04
#    -------------------------- ------------- 2.1/3.2 MB 376.4 kB/s eta 0:00:03
#    -------------------------- ------------- 2.1/3.2 MB 376.4 kB/s eta 0:00:03
#    ----------------------------- ---------- 2.4/3.2 MB 387.9 kB/s eta 0:00:03
#    ----------------------------- ---------- 2.4/3.2 MB 387.9 kB/s eta 0:00:03
#    ----------------------------- ---------- 2.4/3.2 MB 387.9 kB/s eta 0:00:03
#    -------------------------------- ------- 2.6/3.2 MB 394.3 kB/s eta 0:00:02
#    -------------------------------- ------- 2.6/3.2 MB 394.3 kB/s eta 0:00:02
#    ------------------------------------ --- 2.9/3.2 MB 415.3 kB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 444.0 kB/s eta 0:00:00
# Downloading ibm_platform_services-0.66.2-py3-none-any.whl (363 kB)
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading ibm_cloud_sdk_core-3.24.2-py3-none-any.whl (75 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading pyspnego-0.11.2-py3-none-any.whl (130 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading sspilib-0.3.1-cp312-cp312-win_amd64.whl (625 kB)
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.0 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/626.0 kB 364.6 kB/s eta 0:00:01
#    -------------------------------------- 626.0/626.0 kB 408.4 kB/s eta 0:00:00
# Installing collected packages: urllib3, sspilib, PyJWT, requests, pyspnego, ibm_cloud_sdk_core, requests-ntlm, ibm-platform-services, qiskit_ibm_runtime
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# Successfully installed PyJWT-2.10.1 ibm-platform-services-0.66.2 ibm_cloud_sdk_core-3.24.2 pyspnego-0.11.2 qiskit_ibm_runtime-0.40.1 requests-2.32.4 requests-ntlm-1.3.0 sspilib-0.3.1 urllib3-2.4.0

# %% [markdown]
# 1. Create the circuit for superdense coding (using 2 qubits and 2 classical bits) and check its validity using Statevector for all the 4 possible cases.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_city
import matplotlib.pyplot as plt

backend1 = AerSimulator()

def superdense_encode(bits):
    qc = QuantumCircuit(2)
    
    # Step 1: Create Bell pair
    qc.h(0)
    qc.cx(0, 1)

    # Step 2: Alice applies gates based on bits
    if bits == '01':
        qc.z(0)
    elif bits == '10':
        qc.x(0)
    elif bits == '11':
        qc.x(0)
        qc.z(0)

    # Step 3: Bob decodes
    qc.cx(0, 1)
    qc.h(0)
    
    return qc

# Run all 4 cases and print statevectors
for message in ['00', '01', '10', '11']:
    qc = superdense_encode(message)
    sv = Statevector.from_instruction(qc)
    print("Message: " + str(message))
    print(sv)
# Out:
# Message: 00
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2))
# Message: 01
# Statevector([0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2))
# Message: 10
# Statevector([0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#             dims=(2, 2))
# Message: 11
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#             dims=(2, 2))

# %% [markdown]
# 2. Run it on AerSimulator (no noise) and Real Quantum Hardware (1024 shots for both) for transmitting the classical bits 11 and find how many times do you send correct message by plotting histogram.

# %%
##AerSimulator (No Noise)

from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import pickle

# Step 1: Build the superdense coding circuit for message '11'
qc = QuantumCircuit(2, 2)

# Create entanglement
qc.h(0)
qc.cx(0, 1)

# Alice encodes '11' using X and Z gates
qc.x(0)
qc.z(0)

# Bob decodes
qc.cx(0, 1)
qc.h(0)

# Measurement
qc.measure([0, 1], [0, 1])

# Step 2: Use AerSimulator (no noise)
sim = AerSimulator()

# Transpile the circuit for the simulator
compiled_with_aer = transpile(qc, sim)

# Run the circuit
job1 = sim.run(compiled_with_aer, shots=1024)
result = job1.result()
counts_aer_simulator = result.get_counts(compiled_with_aer)

# Display counts
print("Counts:", counts_aer_simulator)

# Step 3: Plot the results
plot_histogram(counts_aer_simulator)
# Out:
# Counts: {'11': 1024}

# %%
##Real Hardware (pickle)

from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import pickle

# Step 1: Build the superdense coding circuit for message '11'
qc = QuantumCircuit(2, 2)

# Create entanglement
qc.h(0)
qc.cx(0, 1)

# Alice encodes '11' using X and Z gates
qc.x(0)
qc.z(0)

# Bob decodes
qc.cx(0, 1)
qc.h(0)

# Measurement
qc.measure([0, 1], [0, 1])

# Step 2: Use Real Hardware
with open("ibm_brisbane_noise_model.pkl","rb") as f:
    noise_model, basis_gates = pickle.load(f)

backend = AerSimulator(noise_model = noise_model, basis_gates = basis_gates)

# Transpile the circuit for the simulator
compiled_with_real_hardware = transpile(qc,backend)

# Run the circuit
job2 = backend.run(compiled_with_real_hardware, shots=1024)
result = job2.result()
counts_real_hardware = result.get_counts(compiled_with_real_hardware)

# Display counts
print("Counts:", counts_real_hardware)

# Step 3: Plot the results
plot_histogram(counts_real_hardware)
# Out:
# Counts: {'11': 974, '10': 35, '01': 14, '00': 1}

# %% [markdown]
#  (ii) Firstly you will use the nosie-free AerSimulator to check if you circuit is working fine.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_city
import matplotlib.pyplot as plt

def word_to_binary(word):
    binary = ''.join(format(ord(c), '08b') for c in word)
    return binary 
# Remember for each letter in your word it will add 8 more bits so choose a relatively shorter word ~12 letters or less

def binary_to_word(binary_str):
    # Pad with zeros if length not multiple of 8
    padded = binary_str.ljust((len(binary_str) + 7) // 8 * 8, '0')
    return ''.join(chr(int(padded[i:i+8], 2)) for i in range(0, len(padded), 8))

string = 'abbas'
nombre = word_to_binary(string)
bit_pairs = [nombre[i:i+2] for i in range(0,len(nombre),2)]

sim = AerSimulator()
received_bits = ''

for pair in bit_pairs:
    # 1. Create a 2-qubit, 2-classical-bit circuit
    qc = QuantumCircuit(2, 2)

    # 2. Create Bell pair (Alice and Bob share entanglement)
    qc.h(0)
    qc.cx(0, 1)

    # 3. Encode message on Alice's qubit based on 2 classical bits
    if pair == '00':
        pass  # no gates
    elif pair == '01':
        qc.x(0)
    elif pair == '10':
        qc.z(0)
    elif pair == '11':
        qc.z(0)
        qc.x(0)

    # 4. Bob's decoding
    qc.cx(0, 1)
    qc.h(0)

    # 5. Measurement
    qc.measure([0, 1], [0, 1])

    # 6. Simulate with Aer
    compiled = transpile(qc, sim)
    result = sim.run(compiled, shots=1).result()
    counts = result.get_counts()
    
    # Extract the only result and reverse it
    raw_bit = list(counts.keys())[0]
    received_bit = raw_bit[::-1]
    received_bits += received_bit

    print(f"Sent: {pair}, Received: {received_bit}")

# Trim and decode
received_bits = received_bits[:len(nombre)]
decoded_word = binary_to_word(received_bits)

print("\nOriginal Word:", string)
print("Decoded Word: ", decoded_word)
# Out:
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 10
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 10
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 11, Received: 11
# Sent: 00, Received: 00
# Sent: 11, Received: 11
#
# Original Word: abbas
# Decoded Word:  abbas

# %% [markdown]
# (iii) Now you will run this circuit on a real hardware to send a message. Remember that real hardwares have errors so the word that you are trying to send might change into something entirely different upon its arrival at the reciever's end.

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_city
import matplotlib.pyplot as plt
from qiskit_aer.noise import NoiseModel
import pickle

def word_to_binary(word):
    binary = ''.join(format(ord(c), '08b') for c in word)
    return binary 
# Remember for each letter in your word it will add 8 more bits so choose a relatively shorter word ~12 letters or less

def binary_to_word(binary_str):
    # Pad with zeros if length not multiple of 8
    padded = binary_str.ljust((len(binary_str) + 7) // 8 * 8, '0')
    return ''.join(chr(int(padded[i:i+8], 2)) for i in range(0, len(padded), 8))

string = 'abbas'
nombre = word_to_binary(string)
bit_pairs = [nombre[i:i+2] for i in range(0,len(nombre),2)]

with open("ibm_brisbane_noise_model.pkl","rb") as f:
    noise_model, basis_gates = pickle.load(f)
backend = AerSimulator(noise_model = noise_model, basis_gates = basis_gates)

received_bits = ''

for pair in bit_pairs:
    # 1. Create a 2-qubit, 2-classical-bit circuit
    qc = QuantumCircuit(2, 2)

    # 2. Create Bell pair (Alice and Bob share entanglement)
    qc.h(0)
    qc.cx(0, 1)

    # 3. Encode message on Alice's qubit based on 2 classical bits
    if pair == '00':
        pass  # no gates
    elif pair == '01':
        qc.x(0)
    elif pair == '10':
        qc.z(0)
    elif pair == '11':
        qc.z(0)
        qc.x(0)

    # 4. Bob's decoding
    qc.cx(0, 1)
    qc.h(0)

    # 5. Measurement
    qc.measure([0, 1], [0, 1])

    # 6. Simulate with Aer
    compiled = transpile(qc, backend)
    result = backend.run(compiled, shots=1).result()
    counts = result.get_counts()
    
    # Extract the only result and reverse it
    raw_bit = list(counts.keys())[0]
    received_bit = raw_bit[::-1]
    received_bits += received_bit

    print(f"Sent: {pair}, Received: {received_bit}")

# Trim and decode
received_bits = received_bits[:len(nombre)]
decoded_word = binary_to_word(received_bits)

print("\nOriginal Word:", string)
print("Decoded Word: ", decoded_word)
# Out:
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 10
# Sent: 01, Received: 00
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 00
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 11, Received: 11
# Sent: 00, Received: 00
# Sent: 11, Received: 11
#
# Original Word: abbas
# Decoded Word:  ab as

# %% [markdown]
# (v) Since in this future qubit transmission is cheaper but not infinitely cheaper, so we have to make sure that correct message is transmitted most certainly as cheaply as possible. Can you find a way through which you can send correct message (almost always) through noisy AerSimulator in as little tries as possible?

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_city
import matplotlib.pyplot as plt
from qiskit_aer.noise import NoiseModel
import pickle

def word_to_binary(word):
    binary = ''.join(format(ord(c), '08b') for c in word)
    return binary 
# Remember for each letter in your word it will add 8 more bits so choose a relatively shorter word ~12 letters or less

def binary_to_word(binary_str):
    # Pad with zeros if length not multiple of 8
    padded = binary_str.ljust((len(binary_str) + 7) // 8 * 8, '0')
    return ''.join(chr(int(padded[i:i+8], 2)) for i in range(0, len(padded), 8))

string = 'abbas'
nombre = word_to_binary(string)
bit_pairs = [nombre[i:i+2] for i in range(0,len(nombre),2)]

with open("ibm_brisbane_noise_model.pkl","rb") as f:
    noise_model, basis_gates = pickle.load(f)

backend = AerSimulator(noise_model = noise_model, basis_gates = basis_gates)
received_bits = ''

for pair in bit_pairs:
    # 1. Create a 2-qubit, 2-classical-bit circuit
    qc = QuantumCircuit(2, 2)

    # 2. Create Bell pair (Alice and Bob share entanglement)
    qc.h(0)
    qc.cx(0, 1)

    # 3. Encode message on Alice's qubit based on 2 classical bits
    if pair == '00':
        pass  # no gates
    elif pair == '01':
        qc.x(0)
    elif pair == '10':
        qc.z(0)
    elif pair == '11':
        qc.z(0)
        qc.x(0)

    # 4. Bob's decoding
    qc.cx(0, 1)
    qc.h(0)

    # 5. Measurement
    qc.measure([0, 1], [0, 1])

    # 6. Simulate with Aer
    compiled = transpile(qc, backend)
    result = backend.run(compiled, shots=1).result()
    counts = result.get_counts()
    
    # Extract the result and reverse it
    raw_bit = list(counts.keys())[0]
    received_bit = raw_bit[::-1]
    received_bits += received_bit

    print(f"Sent: {pair}, Received: {received_bit}")

# Trim and decode
received_bits = received_bits[:len(nombre)]
decoded_word = binary_to_word(received_bits)

print("\nOriginal Word:", string)
print("Decoded Word: ", decoded_word)
# Out:
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 10
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 10, Received: 10
# Sent: 01, Received: 01
# Sent: 10, Received: 10
# Sent: 00, Received: 00
# Sent: 01, Received: 01
# Sent: 01, Received: 01
# Sent: 11, Received: 11
# Sent: 00, Received: 00
# Sent: 11, Received: 11
#
# Original Word: abbas
# Decoded Word:  abbas
